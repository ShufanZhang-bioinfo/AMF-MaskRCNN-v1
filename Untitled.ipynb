# %%
import os
import sys
 
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
from skimage.io import imshow, imread

# %%
root = r'/Users/lovely_shufan/Dropbox (Edison_Lab@UGA)/UGA PhD/image analysis/'
workdir = root + r'workdir_test_image_preprocessing/'
img_dir = root+ r'test_images_four_exp/' #input: image directory
output_dir = workdir + r'output'

os.makedirs(output_dir,exist_ok=True)

# %%
print(os.listdir(img_dir))
img_file = os.path.join(img_dir,'2022_08_30__16_52__0006_Phil_06_s04m1.jpg')
# Out:
# ['2022_08_30__16_52__0006_Phil_06_s04m1.jpg', '2022_08_30__17_01__0023_Phil_23_s06m1.jpg', 'E24W-1_C5_1106_s04_ORG.jpg', '2022_08_30__16_54__0010_Phil_10_s13m2.jpg', '2022_08_30__16_52__0006_Phil_06_s06m1.jpg', '2022_08_30__16_54__0010_Phil_10_s08m2.jpg', '.DS_Store', 'PI297155_A03-Scene-13-ScanRegion12Image%20Export2377.jpg', '2022_08_30__16_54__0010_Phil_10_s15m1.jpg', 'E24W-1_F6_08-122_s07_ORG.jpg', '2022_08_30__16_58__0018_Phil_18_s13m1.jpg', '2022_08_30__16_55__0012_Phil_12_s15m1.jpg', 'NAM10_012_A02-Scene-03-ScanRegion3Image%20Export1997.jpg', 'E24W-1_C5_1106_s06_ORG.jpg', 'PI297155_A03-Scene-08-ScanRegion7Image%20Export2372.jpg', '2022_08_30__16_55__0011_Phil_11_s07m1.jpg', '2022_08_30__16_55__0011_Phil_11_s05m1.jpg', '2022_08_30__16_54__0010_Phil_10_s03m1.jpg', 'E24W-1_C5_0901_s18_ORG.jpg', '2022_08_30__16_56__0013_Phil_13_s06m2.jpg', '2022_08_30__17_01__0023_Phil_23_s12m1.jpg', 'blur', 'NAM10_074_A12-Scene-04-ScanRegion3Image%20Export2092.jpg', '2022_08_30__16_56__0013_Phil_
# ...

# %%
# image processing method 1: greyscale thresholding

# %%
for imgname in os.listdir(img_dir):
    if imgname.endswith(".jpg"):
        print(imgname)
        img_file = os.path.join(img_dir,imgname)
        # reading the image from the same directory
        img = cv.imread(img_file, cv.IMREAD_GRAYSCALE)
        # threshold with the simple binary method
        ret1,simp_thresh = cv.threshold(img,127,255,cv.THRESH_BINARY)

        # Otsu's threshold without any filter
        ret2,simp_thresh_otsu = cv.threshold(img,0,255,cv.THRESH_BINARY+cv.THRESH_OTSU)

        # Otsu's threshold using Gaussian filtering
        blur = cv.GaussianBlur(img,(5,5),0)
        ret3,otsu_filter = cv.threshold(blur,0,255,cv.THRESH_BINARY+cv.THRESH_OTSU)

        # histogram of images
        images = [img, 0, simp_thresh,
                  img, 0, simp_thresh_otsu,
                  blur, 0, otsu_filter]

        titles = ['Original Image','Histogram','Global Thresholding (v=127)',
                  'Original Image','Histogram',"Otsu's Thresholding",
                  'Gaussian filtered Image','Histogram',"Otsu's Thresholding"]

        # using a loop to visualize the different types of methods
        for i in range(3):
            plt.figure(figsize=(10,6))
            plt.subplot(3,3,i*3+1),plt.imshow(images[i*3],'gray')
            plt.title(titles[i*3]), plt.xticks([]), plt.yticks([])
            plt.subplot(3,3,i*3+2),plt.hist(images[i*3].ravel(),256)
            plt.title(titles[i*3+1]), plt.xticks([]), plt.yticks([])
            plt.subplot(3,3,i*3+3),plt.imshow(images[i*3+2],'gray')
            plt.title(titles[i*3+2]), plt.xticks([]), plt.yticks([])
        plt.show()
# Out:
# 2022_08_30__16_52__0006_Phil_06_s04m1.jpg
# 2022_08_30__17_01__0023_Phil_23_s06m1.jpg
# E24W-1_C5_1106_s04_ORG.jpg
# 2022_08_30__16_54__0010_Phil_10_s13m2.jpg
# 2022_08_30__16_52__0006_Phil_06_s06m1.jpg
# 2022_08_30__16_54__0010_Phil_10_s08m2.jpg
# PI297155_A03-Scene-13-ScanRegion12Image%20Export2377.jpg
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/mv/p4jr8xs52gl7rk_wf4pn6mn80000gn/T/ipykernel_34961/660420040.py in <module>
#      29             plt.subplot(3,3,i*3+1),plt.imshow(images[i*3],'gray')
#      30             plt.title(titles[i*3]), plt.xticks([]), plt.yticks([])
# ---> 31             plt.subplot(3,3,i*3+2),plt.hist(images[i*3].ravel(),256)
#      32             plt.title(titles[i*3+1]), plt.xticks([]), plt.yticks([])
#      33             plt.subplot(3,3,i*3+3),plt.imshow(images[i*3+2],'gray')
#
# ...

# %%
# removing color from root images is not a good idea. 
# Two peaks are needed on a histogram to separate background from AMF structures. 
# https://amitprius.medium.com/opencv-adaptive-and-otsu-threshold-in-image-processing-with-python-648b64129876

# %%
# image processing method 2: color channel adjustments

# %%
def channel_statistics(image):
    df_color = []
    for i in range(0, 3):
        max_color = np.max(image[:,:,i])
        mean_color = np.mean(image[:,:,i])
        median_color = np.median(image[:,:,i])
        perc_90 = np.percentile(image[:,:,i], 90, axis=(0,1))
        perc_95 = np.percentile(image[:,:,i], 95, axis=(0,1))
        perc_99 = np.percentile(image[:,:,i], 99, axis=(0,1))
        
        row = (max_color, mean_color, median_color, 
               perc_90, perc_95, perc_99)
        df_color.append(row)
        
    return pd.DataFrame(df_color, 
                        index = ['Red', ' Green', 'Blue'],
                        columns = ['Max', 'Mean', 'Median', 
                                   'P_90',' P_95', 'P_99'])

# %%
# view image by color channels
rgb_list = ['Reds','Greens','Blues']
for imgname in os.listdir(img_dir):
    if imgname.endswith(".jpg"):
        print(imgname)
        img_file = os.path.join(img_dir,imgname)
        # reading the image from the same directory
        img = cv.imread(img_file, cv.IMREAD_COLOR)
        print(np.min(img[:,:,0]))
#         # plot color channels
#         fig, ax = plt.subplots(1, 3, figsize=(15,5), sharey = True)
#         #print(ax)
#         for i in range(3):
#            ax[i].imshow(img[:,:,i], cmap = rgb_list[i])
#            ax[i].set_title(rgb_list[i], fontsize = 15)
        #print(channel_statistics(img))
# Out:
# 2022_08_30__16_52__0006_Phil_06_s04m1.jpg
# 11
# 2022_08_30__17_01__0023_Phil_23_s06m1.jpg
# 0
# E24W-1_C5_1106_s04_ORG.jpg
# 0
# 2022_08_30__16_54__0010_Phil_10_s13m2.jpg
# 0
# 2022_08_30__16_52__0006_Phil_06_s06m1.jpg
# 10
# 2022_08_30__16_54__0010_Phil_10_s08m2.jpg
# 17
# PI297155_A03-Scene-13-ScanRegion12Image%20Export2377.jpg
# 0
# 2022_08_30__16_54__0010_Phil_10_s15m1.jpg
# 13
# E24W-1_F6_08-122_s07_ORG.jpg
# 0
# 2022_08_30__16_58__0018_Phil_18_s13m1.jpg
# 7
# 2022_08_30__16_55__0012_Phil_12_s15m1.jpg
# 8
# NAM10_012_A02-Scene-03-ScanRegion3Image%20Export1997.jpg
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/mv/p4jr8xs52gl7rk_wf4pn6mn80000gn/T/ipykernel_43269/3105313134.py in <module>
#       6         img_file = os.path.join(img_dir,imgname)
#       7         # reading the image from the same directory
# ...
