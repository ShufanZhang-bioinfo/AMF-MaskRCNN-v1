# %% [markdown]
# # Perform parallel inference on a GWAS 2022 Axioscan7 images

# %%
import argparse
import os
import random
import shutil
import time
import warnings
import pickle
import numpy as np
import math
import sys
import copy
import re
import pandas as pd
import matplotlib.pyplot as plt
import json
import cv2
from itertools import compress

import torch
import torch.nn as nn
import detectron2
from detectron2.utils.logger import setup_logger
setup_logger()
from detectron2 import model_zoo
from detectron2.engine import DefaultPredictor,DefaultTrainer,HookBase
from detectron2.config import get_cfg
from detectron2.utils.visualizer import Visualizer,ColorMode,GenericMask
from detectron2.structures import BoxMode
from detectron2.evaluation import COCOEvaluator,inference_on_dataset
from detectron2.data import build_detection_test_loader,DatasetMapper,build_detection_train_loader,MetadataCatalog,DatasetCatalog
import detectron2.data.transforms as T
import detectron2.utils.comm as comm

import ray
import time

import uuid as uuid
from operator import itemgetter
import seaborn as sns

import shapely
import shapely.geometry
from shapely.geometry import Polygon,MultiPolygon,GeometryCollection
from shapely.validation import make_valid
from shapely.geometry import mapping
#import geopandas as gpd

#import imgfileutils as imf
#import segmentation_tools as sgt
from aicsimageio import AICSImage, imread
from skimage import measure, segmentation
from skimage.measure import regionprops
from skimage.color import label2rgb
#import progressbar
from IPython.display import display, HTML
#from MightyMosaic import MightyMosaic

import glob
from PIL import Image
import csv

# %%
# setup directory
root = r'/Users/lovely_shufan/'

project_dir = root + r'Dropbox (Edison_Lab@UGA)/AMF/AMF Imaging 2022/0_inference_using_MaskRCNN_2021/'
output_dir = project_dir + r'2_infer_result/GA_GWAS_2022/'

model_dir = root + r'Dropbox (Edison_Lab@UGA)/AMF/AMF Imaging 2021/2_computer_vision/'

data_dir = r'/Volumes/easystore/GWAS 2022/'

blocks = ['Block2/','Block3/','Block8/']

# %% [markdown]
# ## check available resources on the computer
# Total 20 cores
# Estimated time to do inference on 1 czi image is 40 min
# to finish inference on 337 accessions x 3 untreated blocks x 40 min = 40440 mins = 674 hrs = 28 days on one core or 2 days on 15 cores

# %%
RAY_GCE_TPU_ACCELERATOR_ENDPOINT = (
    "http://metadata.google.internal/computeMetadata/"
    "v1/instance/attributes/accelerator-type"
)
RAY_GCE_TPU_HEADERS = {"Metadata-Flavor": "Google"}
import requests
accelerator_type_request = requests.get(
    RAY_GCE_TPU_ACCELERATOR_ENDPOINT,
    headers=RAY_GCE_TPU_HEADERS,
)

# %%
print(accelerator_type_request)
# Out:
# <Response [200]>

# %%
ray.init()
ray.available_resources()['CPU']
# Out:
# 2023-09-29 12:36:47,304	INFO worker.py:1612 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# 20.0

# %%
ray.init(num_cpus=18, ignore_reinit_error=True)
# Out:
# 2023-10-01 20:54:41,550	INFO worker.py:1612 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# RayContext(dashboard_url='127.0.0.1:8265', python_version='3.8.18', ray_version='2.6.3', ray_commit='8a434b4ee7cd48e60fa1531315d39901fac5d79e', protocol_version=None)

# %% [markdown]
# ## test parallel computing using Ray

# %% [markdown]
# ### Trial 1
# everything seems great, code is working

# %%
@ray.remote
def timer_ray(x):
    time.sleep(1)
    return x

# %%
t0 = time.time()
values = [timer_ray.remote(x) for x in range(4)]
print('Time Elapsed:\t{:.4f}'.format(time.time() - t0))
print(values)

# %%
print(ray.get(values))

# %% [markdown]
# ### Trial 2
# Based on code below, ray.get()is extremely slow. Need to optimize ray.get() behavior

# %%
def busy(i):
    time.sleep(i)
    return i

# %%
@ray.remote
def rbusy(i):
    return busy(i)

# %%
# no parallel
t0 = time.time()
objs = [(i, busy(1.0)) for i in range(5)]
print('Time Elapsed:\t{:.4f}'.format(time.time() - t0))
for i,obj in list(objs):
    print(f'{i}: {obj}')

# %%
# with parallel
t0 = time.time()
objs = [(i, ray.get(rbusy.remote(1.0)), time.time() - t0) for i in range(5)]
end = time.time() - t0
print('Time Elapsed:\t{:.4f}'.format(time.time() - t0))

for i,obj,t in list(objs):
    print('%d: %s (time: %6.3f seconds)' % (i, obj, t))

# %% [markdown]
# This example recreates the problem below. Immediately calling ray.get() on each object ID is effectively blocking the progress, in another word, waited for each remote call to finish before starting the next task. Now we try to solve this by making ray.get() non-blocking.

# %%
t0 = time.time()
ids = [(i, rbusy.remote(1.0), time.time() - t0) for i in range(5)] # only calling object id now
t1 = time.time() - t0
print('Time Elapsed:\t{:.5f}'.format(time.time() - t0))

for i,obj_id,t in list(ids):
    print('%d: %s time: %.5f SECONDS' % (i, obj_id, t))

# %%
t0 = time.time()
for i, obj_id, t in list(ids):
    print('%d: (%s) time: %.5f SECONDS' % (i, ray.get(obj_id), time.time() - t0))

print('Time Elapsed:\t{:.5f}'.format(time.time() - t0))

# %% [markdown]
# The two step process is much faster than directly calling ray.get() after each task. The reason is that while we are waiting for the first task to finish in the second loop, the other four tasks are running in parallel and would finish almost at the same time. We no longer need to wait for the second, third ... task to finish. Therefore, the later ray.get() does not wait long before the object is ready. Now we will generalize this method to task that requires different running time.

# %% [markdown]
# ### Trial 3

# %%
times = range(5,30,5) # 5, 10, ...
ids = [rbusy.remote(i) for i in times]  # Each waits progressively longer
for x in list(zip(times, ids)):        # Show a list of ids and the times each one will take 
    print(x)

# %%
for i in range(1,40): 
    ready, not_ready = ray.wait(ids, num_returns = 2)
    print('iteration:', i) 
    print('Ready length, values: ', len(ready), ray.get(ready))
    print('Not Ready length:', len(not_ready))
    ids = not_ready
    if not ids:
        break

# %%
ids = [rbusy.remote(i) for i in times]  # New set of ids
for i in range(1,40):
    num_returns = 2 if len(ids) >= 2 else len(ids)
    ready, not_ready = ray.wait(ids, num_returns = num_returns)
    print('iteration:', i) 
    print('Ready length, values: ', len(ready), ray.get(ready))
    print('Not Ready length:', len(not_ready))
    ids = not_ready
    if not ids: 
        break

# %% [markdown]
# ## Calculate AXIOSCAN per-channel mean
# 1. by randomly choosing 30 scenes
#     with 1 core
#     with 15 cores
# 2. by randomly choosing 100 images
#     with 15 cores

# %%
def findBGRmean(file):
    czi = AICSImage(file)
    scenes = czi.scenes
    num_scene = len(scenes)
    x = random.randint(0, num_scene-1)
    czi.set_scene(x)
    img = czi.get_image_data("YXS", T=0,C=0,Z=0)
    
    return np.array([np.mean(img[:,:,0]),np.mean(img[:,:,1]),np.mean(img[:,:,2])])

# %%
@ray.remote
def rfindBGRmean(file):
    czi = AICSImage(file)
    scenes = czi.scenes
    x = random.choice(scenes)
    czi.set_scene(x)
    img = czi.get_image_data("YXS", T=0,C=0,Z=0)
    
    return [np.mean(img[:,:,0]),np.mean(img[:,:,1]),np.mean(img[:,:,2])]

# %%
# 64G memory limit
memory_limit = 64 * 1024 * 1024 * 1024
print(memory_limit)

# %%
# list all files in block2
all_file = [os.path.join(path, name) 
 for path, dirs, files in os.walk(os.path.join(data_dir, 'Block2/'), topdown=False)
 for name in files
if name.endswith('.czi')]

# %%
print(len(all_file))
print(all_file[0])

# %% [markdown]
# ### randomly choose 30 scenes and run with 1 core

# %%
# randomly choose 30 scenes
sample30 = random.sample(all_file,30)

# %%
# calculate channel means without parallel
n=0
t0 = time.time()
for czi in sampleA:
    n = n+1
    print(n)
    print(findBGRmean(czi))
    print('Time Elapsed:\t{:.4f}'.format(time.time() - t0))
print('Total Time Elapsed:\t{:.4f}'.format(time.time() - t0))

# %% [markdown]
# ### randomly choose 30 scenes and run with 15 cores

# %%
# test to make sure the code is finishing in reasonable amount of time
id30 = [rfindBGRmean.remote(czi) for czi in sample30]
t0 = time.time()
for i in range(0,30):
    ready, not_ready = ray.wait(id30, num_returns = 1)
    print('iteration:', i) 
    print('Ready length, values: ', len(ready), ray.get(ready))
    print('Not Ready length:', len(not_ready))
    id30 = not_ready
    if not ids: 
        break
print('Time Elapsed:\t{:.4f}'.format(time.time() - t0))
#print(np.mean(np.array(ray.get(values30)),axis=0))
#print('Time Elapsed:\t{:.4f}'.format(time.time() - t0))

# %%
id30 = [rfindBGRmean.remote(czi) for czi in sample30]
results = []
t0 = time.time()
for i in range(1,40):
    ready, not_ready = ray.wait(id30, num_returns = 1)
    print('iteration:', i) 
    results.append(ray.get(ready))
    id30 = not_ready
    if not id30: 
        break
print('Time Elapsed:\t{:.4f}'.format(time.time() - t0))

# %%
block2_means = np.mean(results,axis=0)[0]

# %%
diff_block2 = np.subtract(train_means, block2_means)
print(block2_means)
print(diff_block2)

# %%
# do the same things above for block 3 and 8
means = []
for block in ['Block2/','Block3/','Block8/']:
    print(block)
    results = []
    all_file = []
    t0 = time.time()
    for path, dirs, files in os.walk(os.path.join(data_dir, block), topdown=False):
        for name in files:
            if name.endswith('.czi'):
                all_file.append(os.path.join(path, name))
    sample30 = random.sample(all_file, 30)
    id30 = [rfindBGRmean.remote(czi) for czi in sample30]
    for i in range(1,40):
        ready, not_ready = ray.wait(id30, num_returns = 1)
        print('iteration:', i) 
        results.append(ray.get(ready))
        id30 = not_ready
        if not id30: 
            break
    block_means = np.mean(results,axis=0)[0].tolist()
    means.append(block_means)
    print('Time Elapsed:\t{:.4f}'.format(time.time() - t0))
print('Total Time Elapsed:\t{:.4f}'.format(time.time() - t0))
# Out:
# Block2/
# iteration: 1
# iteration: 2
# iteration: 3
# iteration: 4
# iteration: 5
# iteration: 6
# iteration: 7
# iteration: 8
# iteration: 9
# iteration: 10
# iteration: 11
# iteration: 12
# iteration: 13
# iteration: 14
# iteration: 15
# iteration: 16
# iteration: 17
# iteration: 18
# iteration: 19
# iteration: 20
# iteration: 21
# iteration: 22
# iteration: 23
# iteration: 24
# iteration: 25
# iteration: 26
# iteration: 27
# iteration: 28
# iteration: 29
# iteration: 30
# Time Elapsed:	119.3953
# Block3/
# iteration: 1
# iteration: 2
# iteration: 3
# iteration: 4
# iteration: 5
# iteration: 6
# iteration: 7
# iteration: 8
# iteration: 9
# iteration: 10
# iteration: 11
# iteration: 12
# iteration: 13
# iteration: 14
# iteration: 15
# iteration: 16
# iteration: 17
# iteration: 18
# iteration: 19
# iteration: 20
# iteration: 21
# iteration: 22
# iteration: 23
# iteration: 24
# iteration: 25
# iteration: 26
# iteration: 27
# iteration: 28
# iteration: 29
# iteration: 30
# Time Elapsed:	112.0988
# Block8/
# iteration: 1
# iteration: 2
# iteration: 3
# iteration: 4
# iteration: 5
# iteration: 6
# iteration: 7
# iteration: 8
# iteration: 9
# iteration: 10
# iteration: 11
# iteration: 12
# iteration: 13
# iteration: 14
# iteration: 15
# iteration: 16
# iteration: 17
# iteration: 18
# iteration: 19
# iteration: 20
# iteration: 21
# iteration: 22
# iteration: 23
# iteration: 24
# iteration: 25
# iteration: 26
# iteration: 27
# iteration: 28
# iteration: 29
# iteration: 30
# Time Elapsed:	103.5872
# Total Time Elapsed:	103.5873

# %%
train_means = np.array([145.85450147081923, 152.11404784018066, 161.0139541272665])

# %% [markdown]
# ### Calculate diff between per channels means for centering

# %%
#print(means)
#print(train_means)
#print(np.subtract(train_means, means))
#diffs = np.subtract(train_means, means)
#diffs = np.reshape(np.append(diff_block2,np.subtract(train_means, means)), (3,3))

diffs = [[10.12746633, 18.06137262, 27.510427], 
         [16.24330208, 23.29101365, 34.06829238], 
         [10.1628206,  16.92133011, 26.18143223]]
print(diffs[0])
# Out:
# [10.12746633, 18.06137262, 27.510427]

# %% [markdown]
# ## parallel inference step-by-step
# 1. for loops to read in czi images
# 2. parallelize at the step of looping by tiles

# %%
classes=['root','AMF internal hypha','AMF external hypha','AMF arbuscule','AMF vesicle','AMF spore','others']

# %%
cfg = get_cfg() # return default configuration
cfg.merge_from_file(model_zoo.get_config_file("COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml")) # copy config files from open source projects

# training configuration
cfg.DATASETS.TEST=()
cfg.DATALOADER.NUM_WORKERS=2
#cfg.SOLVER.IMS_PER_BATCH=args.batch_size

cfg.MODEL.ROI_HEADS.BATCH_SIZE_PER_IMAGE=128 #Number of regions per image used to train RPN. faster, and good enough for this toy dataset (default: 512)
cfg.MODEL.ROI_HEADS.NUM_CLASSES=len(classes)# (see https://detectron2.readthedocs.io/tutorials/datasets.html#update-the-config-for-new-datasets)
cfg.MODEL.BACKBONE.FREEZE_AT=2
cfg.SEED=1
cfg.AUG_FLAG=1

# inference configuration
cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.8  # set threshold for this model
cfg.MODEL.WEIGHTS=os.path.join(model_dir, "Trainset1_model_best.pth") # path to the best model trained
cfg.MODEL.DEVICE='cpu' # use cpu for inference


inf_metadata = MetadataCatalog.get("inference").set(thing_classes=['root','AMF internal hypha','AMF external hypha','AMF arbuscule','AMF vesicle','AMF spore','others'])
predictor = DefaultPredictor(cfg)
# Out:
# [09/29 12:40:39 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from /Users/lovely_shufan/Dropbox (Edison_Lab@UGA)/AMF/AMF Imaging 2021/2_computer_vision/Trainset1_model_best.pth ...
# The checkpoint state_dict contains keys that are not used by the model:
#   pixel_mean
#   pixel_std

# %%
diff = [10.12746633, 18.06137262, 27.510427]
# Out:
# 2023-10-01 22:14:49,574	WARNING worker.py:2037 -- The autoscaler failed with the following error:
# Terminated with signal 15
#   File "/Users/lovely_shufan/opt/anaconda3/envs/detectron2-py38/lib/python3.8/site-packages/ray/autoscaler/_private/monitor.py", line 720, in <module>
#     monitor.run()
#   File "/Users/lovely_shufan/opt/anaconda3/envs/detectron2-py38/lib/python3.8/site-packages/ray/autoscaler/_private/monitor.py", line 595, in run
#     self._run()
#   File "/Users/lovely_shufan/opt/anaconda3/envs/detectron2-py38/lib/python3.8/site-packages/ray/autoscaler/_private/monitor.py", line 449, in _run
#     time.sleep(AUTOSCALER_UPDATE_INTERVAL_S)

# %%
diff_expanded = diff[:, np.newaxis, np.newaxis]

# %%
def centering2train(diff, img):
    row = img.shape[0]
    col = img.shape[1]
    times = row * col
    for i in range(0,3,1):
        diffarray = np.repeat(diff[i], times, axis = 0)
        diffmx = diffarray.reshape((row,col))
        img[:,:,i] = np.add(img[:,:,i],diffmx)
        img[img > 255] = 255
        img[img < 0] = 0
    return img

def padImg(img, tilex, tiley):
    '''
    :param img:
    :return padded img:
    
    :rtype ndnumpy.array:
    Objective: output a padded image dividle by tile size
    '''
    y = img.shape[0]
    x = img.shape[1]
    pad_top = tiley - (y % tiley)
    pad_lft = tilex - (x % tilex)
    img = cv2.copyMakeBorder(img,pad_top,0,pad_lft,0,cv2.BORDER_CONSTANT,value=[0,0,0])
    
    return img

# %%
@ray.remote
def inference(pathtofile, block, diff, predictor):
    blklist = []
    imgidlist = []
    sceneidlist = []
    tileidlist = []
    classlist = []
    confscorelist=[]
    arealist = []

    # read in czi
    czi = AICSImage(pathtofile)
   
    for scene in czi.scenes[0:2]:
        # extract image by scene
        czi.set_scene(scene)
        img = czi.get_image_data("YXS", T=0,C=0,Z=0) # numpy.ndarray
                
        # pad image
        img = padImg(img, 2560, 1920)
    
        # centering
        img = centering2train(diff, img)
                 
        # tiling
        for i in range(0,img.shape[0],1920):
            for j in range(0,img.shape[1],2560):
                xmin = j
                xmax = j + 2560
                ymin = i
                ymax = i + 1920
                tile_id = str(xmin)+"_"+str(ymin)+"_"+str(xmax)+"_"+str(ymax)
                subimg = img[ymin:ymax,xmin:xmax]
                outputs = predictor(subimg)
                        
                #inference outputs
                clasind = outputs['instances'].get('pred_classes')
                allmasks = outputs['instances'].get('pred_masks')
                allscores = outputs['instances'].get('scores')
            
                num_seg = clasind.size()[0]
            
                if num_seg != 0: # only save an entry when the image contains a segmentation
                    blklist = blklist + np.repeat(block[:-1], num_seg).tolist()
                    imgidlist = imgidlist + np.repeat(pathtofile, num_seg).tolist()
                    sceneidlist = sceneidlist + np.repeat(scene, num_seg).tolist()
                    tileidlist = tileidlist + np.repeat(tile_id, num_seg).tolist()
                    confscorelist = confscorelist + allscores.tolist()
                
                    # calculate the area of segmentation
                    v = Visualizer(subimg[:, :, ::-1], MetadataCatalog.get("inference"), scale=1.0)
                    for i in range(0,num_seg,1):
                        #calculate mask area
                        locmask = np.asarray(allmasks[i,:,:])
                        gmask = GenericMask(locmask,v.output.height,v.output.width)
                        if gmask.polygons:
                            mergpolygon = gmask.polygons[0]
                            all_points_x = mergpolygon[::2]
                            all_points_y = mergpolygon[1::2]
                            pgon = Polygon(zip(all_points_x,all_points_y))
                            arealist.append(pgon.area)
                            # class index to class name
                            classlist.append(classes[clasind.tolist()[i]])
                        else:
                            continue  # Skip this iteration

    # export inference result as df
    infresults = pd.DataFrame({
    'block': blklist,
    'filename': imgidlist,
    'scene': sceneidlist,
    'tile': tileidlist,
    'annotations': classlist,
    'area': arealist,
    'confidenceScore': confscorelist})
    
    # delete 
    return infresults

# %% [markdown]
# ## make a test inference run for only two images and two scenes per image

# %%
#test_images = os.listdir(os.path.join(data_dir, 'Block2/'))[0:2]
allpath2block2img = [os.path.join(path,name) for path, dirs, files in os.walk(os.path.join(data_dir,'Block2/'))
for name in files
if name.endswith('.czi')]

# %%
print(allpath2block2img[0:2])
# Out:
# ['/Volumes/easystore/GWAS 2022/Block2/e2.1_PI6/e2.1_PI656065_C0.czi', '/Volumes/easystore/GWAS 2022/Block2/PI144134/PI144134_C12_R16.czi']

# %%
ids = [inference.remote(path, 'Block2/', diffs[0], predictor) 
       for path in allpath2block2img[0:2]]

results = list()
t0 = time.time()
for i in range(1,340,1):
    ready, not_ready = ray.wait(ids, num_returns = 1)
    print('working on image:', i) 
    results.append(ray.get(ready))
    ids = not_ready
    if not ids: 
        break
    print('Time Elapsed:\t{:.4f}'.format(time.time() - t0))
print('Total Time Elapsed:\t{:.4f}'.format(time.time() - t0))
# Out:
# (inference pid=21380) The checkpoint state_dict contains keys that are not used by the model:
# (inference pid=21380)   pixel_mean
# (inference pid=21380)   pixel_std
# (inference pid=21380) The checkpoint state_dict contains keys that are not used by the model: [repeated 4x across cluster]
# (inference pid=21380)   pixel_std [repeated 8x across cluster]
# (inference pid=21380) The checkpoint state_dict contains keys that are not used by the model: [repeated 4x across cluster]
# (inference pid=21380)   pixel_std [repeated 8x across cluster]
# (inference pid=21380) The checkpoint state_dict contains keys that are not used by the model: [repeated 4x across cluster]
# (inference pid=21380)   pixel_std [repeated 8x across cluster]
# (inference pid=21376) The checkpoint state_dict contains keys that are not used by the model: [repeated 4x across cluster]
# (inference pid=21376)   pixel_std [repeated 8x across cluster]
# (inference pid=21376) The checkpoint state_dict contains keys that are not used by the model: [repeated 4x across cluster]
# (inference pid=21376)   pixel_std [repeated 8x across cluster]
# (inference pid=21376) The checkpoint state_dict contains keys that are not used by the model: [repeated 4x across cluster]
# (inference pid=21376)   pixel_std [repeated 8x across cluster]
# (inference pid=21376) The checkpoint state_dict contains keys that are not used by the model: [repeated 4x across cluster]
# (inference pid=21376)   pixel_std [repeated 8x across cluster]
# (inference pid=21376) The checkpoint state_dict contains keys that are not used by the model: [repeated 4x across cluster]
# (inference pid=21376)   pixel_std [repeated 8x across cluster]
# (inference pid=21376) The checkpoint state_dict contains keys that are not used by the model: [repeated 4x across cluster]
# (inference pid=21376)   pixel_std [repeated 8x across cluster]
# (inference pid=21380) The checkpoint state_dict contains keys that are not used by the model: [repeated 3x across cluster]
# (inference pid=21380)   pixel_std [repeated 6x across cluster]
# (inference pid=21376) The checkpoint state_dict contains keys that are not used by the model: [repeated 3x across cluster]
# (inference pid=21376)   pixel_std [repeated 6x across cluster]
# (inference pid=21376) The checkpoint state_dict contains keys that are not used by the model: [repeated 4x across cluster]
# (inference pid=21376)   pixel_std [repeated 8x across cluster]
# (inference pid=21376) The checkpoint state_dict contains keys that are not used by the model: [repeated 4x across cluster]
# (inference pid=21376)   pixel_std [repeated 8x across cluster]
# (inference pid=21376) The checkpoint state_dict contains keys that are not used by the model: [repeated 4x across cluster]
# (inference pid=21376)   pixel_std [repeated 8x across cluster]
# (inference pid=21376) The checkpoint state_dict contains keys that are not used by the model: [repeated 4x across cluster]
# (inference pid=21376)   pixel_std [repeated 8x across cluster]
# (inference pid=21376) The checkpoint state_dict contains keys that are not used by the model: [repeated 4x across cluster]
# (inference pid=21376)   pixel_std [repeated 8x across cluster]
# (inference pid=21376) The checkpoint state_dict contains keys that are not used by the model: [repeated 4x across cluster]
# (inference pid=21376)   pixel_std [repeated 8x across cluster]
# (inference pid=21376) The checkpoint state_dict contains keys that are not used by the model: [repeated 4x across cluster]
# (inference pid=21376)   pixel_std [repeated 8x across cluster]
# (inference pid=21376) The checkpoint state_dict contains keys that are not used by the model: [repeated 4x across cluster]
# (inference pid=21376)   pixel_std [repeated 8x across cluster]
# working on image: 1
# Time Elapsed:	159.0395
# (inference pid=21376) The checkpoint state_dict contains keys that are not used by the model: [repeated 3x across cluster]
# (inference pid=21376)   pixel_std [repeated 6x across cluster]
# working on image: 2
# Total Time Elapsed:	166.3434

# %%
print(type(results[0][0]))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
print(len(results))
print(len(results[0][0]))
print(len(results[1][0]))
# Out:
# 2
# 18
# 11

# %%
df = results[0][0]
for i in range(1,len(results),1):
    newdf = results[i][0]
    df = pd.concat([df, newdf], axis=0)
    
display(df)
print(len(df))
# Out:
#      block                                           filename        scene  \
# 0   Block2  /Volumes/easystore/GWAS 2022/Block2/PI144134/P...  ScanRegion0
# 1   Block2  /Volumes/easystore/GWAS 2022/Block2/PI144134/P...  ScanRegion0
# 2   Block2  /Volumes/easystore/GWAS 2022/Block2/PI144134/P...  ScanRegion0
# 3   Block2  /Volumes/easystore/GWAS 2022/Block2/PI144134/P...  ScanRegion0
# 4   Block2  /Volumes/easystore/GWAS 2022/Block2/PI144134/P...  ScanRegion0
# 5   Block2  /Volumes/easystore/GWAS 2022/Block2/PI144134/P...  ScanRegion0
# 6   Block2  /Volumes/easystore/GWAS 2022/Block2/PI144134/P...  ScanRegion0
# 7   Block2  /Volumes/easystore/GWAS 2022/Block2/PI144134/P...  ScanRegion0
# 8   Block2  /Volumes/easystore/GWAS 2022/Block2/PI144134/P...  ScanRegion0
# 9   Block2  /Volumes/easystore/GWAS 2022/Block2/PI144134/P...  ScanRegion0
# 10  Block2  /Volumes/easystore/GWAS 2022/Block2/PI144134/P...  ScanRegion0
# 11  Block2  /Volumes/easystore/GWAS 2022/Block2/PI144134/P...  ScanRegion1
# 12  Block2  /Volumes/easystore/GWAS 2022/Block2/PI144134/P...  ScanRegion1
# 13  Block2  /Volumes/easystore/GWAS 2022/Block2/PI144134/P...  ScanRegion1
# 14  Block2  /Volumes/easystore/GWAS 2022/Block2/PI144134/P...  ScanRegion1
# 15  Block2  /Volumes/easystore/GWAS 2022/Block2/PI144134/P...  ScanRegion1
# 16  Block2  /Volumes/easystore/GWAS 2022/Block2/PI144134/P...  ScanRegion1
# 17  Block2  /Volumes/easystore/GWAS 2022/Block2/PI144134/P...  ScanRegion1
# 0   Block2  /Volumes/easystore/GWAS 2022/Block2/e2.1_PI6/e...  ScanRegion0
# 1   Block2  /Volumes/easystore/GWAS 2022/Block2/e2.1_PI6/e...  ScanRegion0
# 2   Block2  /Volumes/easystore/GWAS 2022/Block2/e2.1_PI6/e...  ScanRegion0
# 3   Block2  /Volumes/easystore/GWAS 2022/Block2/e2.1_PI6/e...  ScanRegion0
# 4   Block2  /Volumes/easystore/GWAS 2022/Block2/e2.1_PI6/e...  ScanRegion1
# 5   Block2  /Volumes/easystore/GWAS 2022/Block2/e2.1_PI6/e...  ScanRegion1
# 6   Block2  /Volumes/easystore/GWAS 2022/Block2/e2.1_PI6/e...  ScanRegion1
# 7   Block2  /Volumes/easystore/GWAS 2022/Block2/e2.1_PI6/e...  ScanRegion1
# 8   Block2  /Volumes/easystore/GWAS 2022/Block2/e2.1_PI6/e...  ScanRegion1
# 9   Block2  /Volumes/easystore/GWAS 2022/Block2/e2.1_PI6/e...  ScanRegion1
# 10  Block2  /Volumes/easystore/GWAS 2022/Block2/e2.1_PI6/e...  ScanRegion1
#
#                    tile         annotations       area  confidenceScore
# 0    10240_0_12800_1920  AMF external hypha    11913.0         0.995756
# 1   2560_1920_5120_3840  AMF external hypha    38379.0         0.997879
# 2   2560_1920_5120_3840                root  1274540.0         0.992442
# 3   2560_1920_5120_3840  AMF internal hypha   119245.5         0.900109
# 4      5120_2_7680_1922  AMF external hypha     3243.0         0.878535
# 5    10240_0_12800_1920  AMF external hypha    11913.0         0.995756
# 6   2560_3840_5120_5760                root  2192908.0         0.989744
# 7   2560_3840_5120_5760  AMF external hypha    26620.5         0.955502
# 8   2560_3840_5120_5760  AMF external hypha     3856.0         0.934331
# 9      5120_2_7680_1922  AMF external hypha     3243.0         0.878535
# 10   10240_0_12800_1920  AMF external hypha    11913.0         0.995756
# 11     0_1920_2560_3840  AMF internal hypha      381.5         0.951353
# 12     0_1920_2560_3840  AMF external hypha     5663.5         0.946876
# 13  2560_3840_5120_5760                root  2310446.0         0.993839
# 14  2560_3840_5120_5760  AMF external hypha      655.0         0.967849
# 15  2560_5760_5120_7680                root   521059.0         0.985596
# 16  2560_5760_5120_7680  AMF internal hypha    11600.0         0.852245
# 17  2560_5760_5120_7680  AMF external hypha    10275.5         0.828272
# 0      0_1920_2560_3840  AMF internal hypha   224298.0         0.963034
# 1      0_3840_2560_5760  AMF internal hypha    73366.5         0.967197
# 2   5120_5760_7680_7680                root   662992.5         0.979919
# 3   5120_5760_7680_7680                root   324023.0         0.950457
# 4      2560_0_5120_1920  AMF external hypha     3642.5         0.967518
# 5      0_1920_2560_3840                root   269266.5         0.970873
# 6      2560_0_5120_1920  AMF external hypha     3642.5         0.967518
# 7   2560_3840_5120_5760                root   764041.0         0.984490
# 8   2560_3840_5120_5760  AMF internal hypha    26439.5         0.848968
# 9   5120_5760_7680_7680                root   826635.0         0.995554
# 10  5120_5760_7680_7680                root   458298.5         0.878748
# 29

# %%
a = list()
a.append(results[0][0])
a.append(results[1][0])

# %%
b = pd.concat(a, ignore_index=True)

# %%
print(type(a))
print(type(a[1]))
print(a[0].shape)
print(a[1].shape)
print(type(b))
print(b.shape)

# %%
print(a[0])

# %%
print(a[1])

# %% [markdown]
# ## Inference on all block 2 images but only two scenes per image

# %%
del df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 del df
#
# NameError: name 'df' is not defined

# %%
ids = [inference.remote(os.path.join(path,name), 'Block2/', diffs[0], predictor) 
        for path, dirs, files in os.walk(os.path.join(data_dir, 'Block2/'))
        for name in files
        if name.endswith('.czi')]

results = list() #creates a new dataframe that's empty
t0 = time.time()
for i in range(1,340,1):
    ready, not_ready = ray.wait(ids, num_returns = 1)
    print('working on image:', i) 
    results.append(ray.get(ready))
    ids = not_ready
    if not ids: 
        break
    print('Time Elapsed:\t{:.4f}'.format(time.time() - t0))
print('Total Time Elapsed:\t{:.4f}'.format(time.time() - t0))

#%% Clean-up object store data 
del ids

# %%
df = results[0][0]
for i in range(1,len(results),1):
    newdf = results[i][0]
    df = pd.concat([df, newdf], axis=0)
df.to_csv(os.path.join(output_dir,"block2_segmentation.txt"),index=False)
# Out:
# (inference pid=21896) The checkpoint state_dict contains keys that are not used by the model:
# (inference pid=21896)   pixel_mean
# (inference pid=21896)   pixel_std
# (inference pid=21895) The checkpoint state_dict contains keys that are not used by the model: [repeated 6x across cluster]
# (inference pid=21895)   pixel_std [repeated 12x across cluster]
# (inference pid=21877) The checkpoint state_dict contains keys that are not used by the model: [repeated 6x across cluster]
# (inference pid=21877)   pixel_std [repeated 12x across cluster]
# (inference pid=21379) The checkpoint state_dict contains keys that are not used by the model: [repeated 6x across cluster]
# (inference pid=21379)   pixel_std [repeated 12x across cluster]
# (inference pid=21896) The checkpoint state_dict contains keys that are not used by the model: [repeated 7x across cluster]
# (inference pid=21896)   pixel_std [repeated 14x across cluster]
# (inference pid=21895) The checkpoint state_dict contains keys that are not used by the model: [repeated 5x across cluster]
# (inference pid=21895)   pixel_std [repeated 10x across cluster]
# (inference pid=21877) The checkpoint state_dict contains keys that are not used by the model: [repeated 5x across cluster]
# (inference pid=21877)   pixel_std [repeated 10x across cluster]
# (inference pid=21882) The checkpoint state_dict contains keys that are not used by the model: [repeated 5x across cluster]
# (inference pid=21882)   pixel_std [repeated 10x across cluster]
# (inference pid=21896) The checkpoint state_dict contains keys that are not used by the model: [repeated 5x across cluster]
# (inference pid=21896)   pixel_std [repeated 10x across cluster]
# (inference pid=21877) The checkpoint state_dict contains keys that are not used by the model: [repeated 6x across cluster]
# (inference pid=21877)   pixel_std [repeated 12x across cluster]
# (inference pid=21882) The checkpoint state_dict contains keys that are not used by the model: [repeated 5x across cluster]
# (inference pid=21882)   pixel_std [repeated 10x across cluster]
# (inference pid=21896) The checkpoint state_dict contains keys that are not used by the model: [repeated 5x across cluster]
# (inference pid=21896)   pixel_std [repeated 10x across cluster]
# (inference pid=21877) The checkpoint state_dict contains keys that are not used by the model: [repeated 6x across cluster]
# (inference pid=21877)   pixel_std [repeated 12x across cluster]
# (inference pid=21896) The checkpoint state_dict contains keys that are not used by the model: [repeated 4x across cluster]
# (inference pid=21896)   pixel_std [repeated 8x across cluster]

# %%
print(len(results))
print(len(allpath2block2img))
# Out:
# 339
# 344

# %% [markdown]
# There are 344 images under block 2 for unknown reasons, expected for < 337 images

# %%
# run the remaining images in block 2
remaining_blk2 = allpath2block2img[-5:]
print(len(remaining_blk2))
print(remaining_blk2)
# Out:
# 5
# ['/Volumes/easystore/GWAS 2022/Block2/PI655981/PI655981_C16_R14.czi', '/Volumes/easystore/GWAS 2022/Block2/PI655983/PI655983_C03_R07.czi', '/Volumes/easystore/GWAS 2022/Block2/PI656015/PI656015_C04_R19.czi', '/Volumes/easystore/GWAS 2022/Block2/PI656035/PI656035_C15_R05.czi', '/Volumes/easystore/GWAS 2022/Block2/PI92270/PI92270_C08_R10.czi']

# %%
ids_remain_blk2 = [inference.remote(imgpath, 'Block2/', diffs[0], predictor) 
        for imgpath in remaining_blk2]

results_remain_blk2 = list() #creates a new dataframe that's empty
t0 = time.time()
for i in range(1,340,1):
    ready, not_ready = ray.wait(ids_remain_blk2, num_returns = 1)
    print('working on image:', i) 
    results_remain_blk2.append(ray.get(ready))
    ids_remain_blk2 = not_ready
    if not ids_remain_blk2: 
        break
    print('Time Elapsed:\t{:.4f}'.format(time.time() - t0))
print('Total Time Elapsed:\t{:.4f}'.format(time.time() - t0))
# Out:
# (inference pid=21379) The checkpoint state_dict contains keys that are not used by the model:
# (inference pid=21379)   pixel_mean
# (inference pid=21379)   pixel_std
# (inference pid=21880) The checkpoint state_dict contains keys that are not used by the model: [repeated 6x across cluster]
# (inference pid=21880)   pixel_std [repeated 12x across cluster]
# (inference pid=21898) The checkpoint state_dict contains keys that are not used by the model: [repeated 6x across cluster]
# (inference pid=21898)   pixel_std [repeated 12x across cluster]
# (inference pid=21877) The checkpoint state_dict contains keys that are not used by the model: [repeated 6x across cluster]
# (inference pid=21877)   pixel_std [repeated 12x across cluster]
# (inference pid=21379) The checkpoint state_dict contains keys that are not used by the model: [repeated 7x across cluster]
# (inference pid=21379)   pixel_std [repeated 14x across cluster]
# (inference pid=21880) The checkpoint state_dict contains keys that are not used by the model: [repeated 6x across cluster]
# (inference pid=21880)   pixel_std [repeated 12x across cluster]
# (inference pid=21898) The checkpoint state_dict contains keys that are not used by the model: [repeated 6x across cluster]
# (inference pid=21898)   pixel_std [repeated 12x across cluster]
# (inference pid=21879) The checkpoint state_dict contains keys that are not used by the model: [repeated 6x across cluster]
# (inference pid=21879)   pixel_std [repeated 12x across cluster]
# (inference pid=21877) The checkpoint state_dict contains keys that are not used by the model: [repeated 6x across cluster]
# (inference pid=21877)   pixel_std [repeated 12x across cluster]
# (inference pid=21379) The checkpoint state_dict contains keys that are not used by the model: [repeated 6x across cluster]
# (inference pid=21379)   pixel_std [repeated 12x across cluster]
# (inference pid=21880) The checkpoint state_dict contains keys that are not used by the model: [repeated 6x across cluster]
# (inference pid=21880)   pixel_std [repeated 12x across cluster]
# (inference pid=21898) The checkpoint state_dict contains keys that are not used by the model: [repeated 6x across cluster]
# (inference pid=21898)   pixel_std [repeated 12x across cluster]
# (inference pid=21879) The checkpoint state_dict contains keys that are not used by the model: [repeated 6x across cluster]
# (inference pid=21879)   pixel_std [repeated 12x across cluster]
# (inference pid=21877) The checkpoint state_dict contains keys that are not used by the model: [repeated 6x across cluster]
# (inference pid=21877)   pixel_std [repeated 12x across cluster]
# (inference pid=21379) The checkpoint state_dict contains keys that are not used by the model: [repeated 6x across cluster]
# (inference pid=21379)   pixel_std [repeated 12x across cluster]
# (inference pid=21880) The checkpoint state_dict contains keys that are not used by the model: [repeated 6x across cluster]
# (inference pid=21880)   pixel_std [repeated 12x across cluster]
# (inference pid=21898) The checkpoint state_dict contains keys that are not used by the model: [repeated 6x across cluster]
# (inference pid=21898)   pixel_std [repeated 12x across cluster]
# (inference pid=21877) The checkpoint state_dict contains keys that are not used by the model: [repeated 5x across cluster]
# (inference pid=21877)   pixel_std [repeated 10x across cluster]
# (inference pid=21880) The checkpoint state_dict contains keys that are not used by the model: [repeated 6x across cluster]
# (inference pid=21880)   pixel_std [repeated 12x across cluster]
# (inference pid=21898) The checkpoint state_dict contains keys that are not used by the model: [repeated 6x across cluster]
# (inference pid=21898)   pixel_std [repeated 12x across cluster]
# (inference pid=21379) The checkpoint state_dict contains keys that are not used by the model: [repeated 5x across cluster]
# (inference pid=21379)   pixel_std [repeated 10x across cluster]
# (inference pid=21898) The checkpoint state_dict contains keys that are not used by the model: [repeated 5x across cluster]
# (inference pid=21898)   pixel_std [repeated 10x across cluster]
# (inference pid=21877) The checkpoint state_dict contains keys that are not used by the model: [repeated 7x across cluster]
# (inference pid=21877)   pixel_std [repeated 14x across cluster]
# (inference pid=21379) The checkpoint state_dict contains keys that are not used by the model: [repeated 6x across cluster]
# (inference pid=21379)   pixel_std [repeated 12x across cluster]
# (inference pid=21879) The checkpoint state_dict contains keys that are not used by the model: [repeated 5x across cluster]
# (inference pid=21879)   pixel_std [repeated 10x across cluster]
# (inference pid=21898) The checkpoint state_dict contains keys that are not used by the model: [repeated 6x across cluster]
# (inference pid=21898)   pixel_std [repeated 12x across cluster]
# (inference pid=21880) The checkpoint state_dict contains keys that are not used by the model: [repeated 6x across cluster]
# (inference pid=21880)   pixel_std [repeated 12x across cluster]
# working on image: 1
# Time Elapsed:	176.0011
# (inference pid=21379) The checkpoint state_dict contains keys that are not used by the model: [repeated 6x across cluster]
# (inference pid=21379)   pixel_std [repeated 12x across cluster]
# (inference pid=21879) The checkpoint state_dict contains keys that are not used by the model: [repeated 5x across cluster]
# (inference pid=21879)   pixel_std [repeated 10x across cluster]
# (inference pid=21898) The checkpoint state_dict contains keys that are not used by the model: [repeated 5x across cluster]
# (inference pid=21898)   pixel_std [repeated 10x across cluster]
# (inference pid=21877) The checkpoint state_dict contains keys that are not used by the model: [repeated 5x across cluster]
# (inference pid=21877)   pixel_std [repeated 10x across cluster]
# (inference pid=21379) The checkpoint state_dict contains keys that are not used by the model: [repeated 5x across cluster]
# (inference pid=21379)   pixel_std [repeated 10x across cluster]
# (inference pid=21879) The checkpoint state_dict contains keys that are not used by the model: [repeated 5x across cluster]
# (inference pid=21879)   pixel_std [repeated 10x across cluster]
# (inference pid=21898) The checkpoint state_dict contains keys that are not used by the model: [repeated 5x across cluster]
# (inference pid=21898)   pixel_std [repeated 10x across cluster]
# working on image: 2
# Time Elapsed:	211.5510
# (inference pid=21877) The checkpoint state_dict contains keys that are not used by the model: [repeated 4x across cluster]
# (inference pid=21877)   pixel_std [repeated 8x across cluster]
# (inference pid=21879) The checkpoint state_dict contains keys that are not used by the model: [repeated 4x across cluster]
# (inference pid=21879)   pixel_std [repeated 8x across cluster]
# (inference pid=21898) The checkpoint state_dict contains keys that are not used by the model: [repeated 4x across cluster]
# (inference pid=21898)   pixel_std [repeated 8x across cluster]
# (inference pid=21877) The checkpoint state_dict contains keys that are not used by the model: [repeated 4x across cluster]
# (inference pid=21877)   pixel_std [repeated 8x across cluster]
# (inference pid=21879) The checkpoint state_dict contains keys that are not used by the model: [repeated 4x across cluster]
# (inference pid=21879)   pixel_std [repeated 8x across cluster]
# (inference pid=21898) The checkpoint state_dict contains keys that are not used by the model: [repeated 4x across cluster]
# (inference pid=21898)   pixel_std [repeated 8x across cluster]
# working on image: 3
# Time Elapsed:	245.6804
# working on image: 4
# Time Elapsed:	247.1074
# working on image: 5
# Time Elapsed:	248.2457
# working on image: 6
# Time Elapsed:	248.2457
# working on image: 7
# Time Elapsed:	248.2458
# working on image: 8
# Time Elapsed:	248.2458
# working on image: 9
# Time Elapsed:	248.2458
# working on image: 10
# Time Elapsed:	248.2458
# working on image: 11
# Time Elapsed:	248.2459
# working on image: 12
# Time Elapsed:	248.2459
# working on image: 13
# Time Elapsed:	248.2459
# working on image: 14
# Time Elapsed:	248.2459
# working on image: 15
# Time Elapsed:	248.2460
# working on image: 16
# Time Elapsed:	248.2460
# working on image: 17
# Time Elapsed:	248.2460
# working on image: 18
# Time Elapsed:	248.2461
# working on image: 19
# Time Elapsed:	248.2461
# working on image: 20
# Time Elapsed:	248.2461
# working on image: 21
# Time Elapsed:	248.2461
# working on image: 22
# Time Elapsed:	248.2462
# working on image: 23
# Time Elapsed:	248.2462
# working on image: 24
# Time Elapsed:	248.2462
# working on image: 25
# Time Elapsed:	248.2463
# working on image: 26
# Time Elapsed:	248.2463
# working on image: 27
# Time Elapsed:	248.2463
# working on image: 28
# Time Elapsed:	248.2463
# working on image: 29
# Time Elapsed:	248.2464
# working on image: 30
# Time Elapsed:	248.2464
# working on image: 31
# Time Elapsed:	248.2464
# working on image: 32
# Time Elapsed:	248.2464
# working on image: 33
# Time Elapsed:	248.2465
# working on image: 34
# Time Elapsed:	248.2465
# working on image: 35
# Time Elapsed:	248.2465
# working on image: 36
# Time Elapsed:	248.2466
# working on image: 37
# Time Elapsed:	248.2466
# working on image: 38
# Time Elapsed:	248.2466
# working on image: 39
# Time Elapsed:	248.2466
# working on image: 40
# Time Elapsed:	248.2467
# working on image: 41
# Time Elapsed:	248.2467
# working on image: 42
# Time Elapsed:	248.2467
# working on image: 43
# Time Elapsed:	248.2467
# working on image: 44
# Time Elapsed:	248.2468
# working on image: 45
# Time Elapsed:	248.2468
# working on image: 46
# Time Elapsed:	248.2468
# working on image: 47
# Time Elapsed:	248.2468
# working on image: 48
# Time Elapsed:	248.2469
# working on image: 49
# Time Elapsed:	248.2469
# working on image: 50
# Time Elapsed:	248.2469
# working on image: 51
# Time Elapsed:	248.2469
# working on image: 52
# Time Elapsed:	248.2470
# working on image: 53
# Time Elapsed:	248.2470
# working on image: 54
# Time Elapsed:	248.2470
# working on image: 55
# Time Elapsed:	248.2471
# working on image: 56
# Time Elapsed:	248.2471
# working on image: 57
# Time Elapsed:	248.2471
# working on image: 58
# Time Elapsed:	248.2471
# working on image: 59
# Time Elapsed:	248.2472
# working on image: 60
# Time Elapsed:	248.2472
# working on image: 61
# Time Elapsed:	248.2472
# working on image: 62
# Time Elapsed:	248.2472
# working on image: 63
# Time Elapsed:	248.2473
# working on image: 64
# Time Elapsed:	248.2473
# working on image: 65
# Time Elapsed:	248.2473
# working on image: 66
# Time Elapsed:	248.2474
# working on image: 67
# Time Elapsed:	248.2474
# working on image: 68
# Time Elapsed:	248.2474
# working on image: 69
# Time Elapsed:	248.2474
# working on image: 70
# Time Elapsed:	248.2475
# working on image: 71
# Time Elapsed:	248.2475
# working on image: 72
# Time Elapsed:	248.2475
# working on image: 73
# Time Elapsed:	248.2475
# working on image: 74
# Time Elapsed:	248.2476
# working on image: 75
# Time Elapsed:	248.2476
# working on image: 76
# Time Elapsed:	248.2476
# working on image: 77
# Time Elapsed:	248.2477
# working on image: 78
# Time Elapsed:	248.2477
# working on image: 79
# Time Elapsed:	248.2477
# working on image: 80
# Time Elapsed:	248.2477
# working on image: 81
# Time Elapsed:	248.2478
# working on image: 82
# Time Elapsed:	248.2478
# working on image: 83
# Time Elapsed:	248.2478
# working on image: 84
# Time Elapsed:	248.2478
# working on image: 85
# Time Elapsed:	248.2479
# working on image: 86
# Time Elapsed:	248.2479
# working on image: 87
# Time Elapsed:	248.2479
# working on image: 88
# Time Elapsed:	248.2479
# working on image: 89
# Time Elapsed:	248.2480
# working on image: 90
# Time Elapsed:	248.2480
# working on image: 91
# Time Elapsed:	248.2480
# working on image: 92
# Time Elapsed:	248.2481
# working on image: 93
# Time Elapsed:	248.2481
# working on image: 94
# Time Elapsed:	248.2481
# working on image: 95
# Time Elapsed:	248.2481
# working on image: 96
# Time Elapsed:	248.2482
# working on image: 97
# Time Elapsed:	248.2482
# working on image: 98
# Time Elapsed:	248.2482
# working on image: 99
# Time Elapsed:	248.2482
# working on image: 100
# Time Elapsed:	248.2483
# working on image: 101
# Time Elapsed:	248.2483
# working on image: 102
# Time Elapsed:	248.2483
# working on image: 103
# Time Elapsed:	248.2483
# working on image: 104
# Time Elapsed:	248.2484
# working on image: 105
# Time Elapsed:	248.2484
# working on image: 106
# Time Elapsed:	248.2484
# working on image: 107
# Time Elapsed:	248.2484
# working on image: 108
# Time Elapsed:	248.2485
# working on image: 109
# Time Elapsed:	248.2485
# working on image: 110
# Time Elapsed:	248.2485
# working on image: 111
# Time Elapsed:	248.2486
# working on image: 112
# Time Elapsed:	248.2486
# working on image: 113
# Time Elapsed:	248.2486
# working on image: 114
# Time Elapsed:	248.2486
# working on image: 115
# Time Elapsed:	248.2487
# working on image: 116
# Time Elapsed:	248.2487
# working on image: 117
# Time Elapsed:	248.2487
# working on image: 118
# Time Elapsed:	248.2487
# working on image: 119
# Time Elapsed:	248.2488
# working on image: 120
# Time Elapsed:	248.2488
# working on image: 121
# Time Elapsed:	248.2488
# working on image: 122
# Time Elapsed:	248.2488
# working on image: 123
# Time Elapsed:	248.2489
# working on image: 124
# Time Elapsed:	248.2489
# working on image: 125
# Time Elapsed:	248.2489
# working on image: 126
# Time Elapsed:	248.2490
# working on image: 127
# Time Elapsed:	248.2490
# working on image: 128
# Time Elapsed:	248.2490
# working on image: 129
# Time Elapsed:	248.2490
# working on image: 130
# Time Elapsed:	248.2491
# working on image: 131
# Time Elapsed:	248.2491
# working on image: 132
# Time Elapsed:	248.2491
# working on image: 133
# Time Elapsed:	248.2491
# working on image: 134
# Time Elapsed:	248.2492
# working on image: 135
# Time Elapsed:	248.2492
# working on image: 136
# Time Elapsed:	248.2492
# working on image: 137
# Time Elapsed:	248.2492
# working on image: 138
# Time Elapsed:	248.2493
# working on image: 139
# Time Elapsed:	248.2493
# working on image: 140
# Time Elapsed:	248.2493
# working on image: 141
# Time Elapsed:	248.2494
# working on image: 142
# Time Elapsed:	248.2494
# working on image: 143
# Time Elapsed:	248.2494
# working on image: 144
# Time Elapsed:	248.2494
# working on image: 145
# Time Elapsed:	248.2495
# working on image: 146
# Time Elapsed:	248.2495
# working on image: 147
# Time Elapsed:	248.2495
# working on image: 148
# Time Elapsed:	248.2495
# working on image: 149
# Time Elapsed:	248.2496
# working on image: 150
# Time Elapsed:	248.2496
# working on image: 151
# Time Elapsed:	248.2496
# working on image: 152
# Time Elapsed:	248.2496
# working on image: 153
# Time Elapsed:	248.2497
# working on image: 154
# Time Elapsed:	248.2497
# working on image: 155
# Time Elapsed:	248.2497
# working on image: 156
# Time Elapsed:	248.2498
# working on image: 157
# Time Elapsed:	248.2498
# working on image: 158
# Time Elapsed:	248.2498
# working on image: 159
# Time Elapsed:	248.2498
# working on image: 160
# Time Elapsed:	248.2499
# working on image: 161
# Time Elapsed:	248.2499
# working on image: 162
# Time Elapsed:	248.2499
# working on image: 163
# Time Elapsed:	248.2499
# working on image: 164
# Time Elapsed:	248.2500
# working on image: 165
# Time Elapsed:	248.2500
# working on image: 166
# Time Elapsed:	248.2500
# working on image: 167
# Time Elapsed:	248.2500
# working on image: 168
# Time Elapsed:	248.2501
# working on image: 169
# Time Elapsed:	248.2501
# working on image: 170
# Time Elapsed:	248.2501
# working on image: 171
# Time Elapsed:	248.2501
# working on image: 172
# Time Elapsed:	248.2502
# working on image: 173
# Time Elapsed:	248.2502
# working on image: 174
# Time Elapsed:	248.2502
# working on image: 175
# Time Elapsed:	248.2503
# working on image: 176
# Time Elapsed:	248.2503
# working on image: 177
# Time Elapsed:	248.2503
# working on image: 178
# Time Elapsed:	248.2503
# working on image: 179
# Time Elapsed:	248.2504
# working on image: 180
# Time Elapsed:	248.2504
# working on image: 181
# Time Elapsed:	248.2504
# working on image: 182
# Time Elapsed:	248.2504
# working on image: 183
# Time Elapsed:	248.2505
# working on image: 184
# Time Elapsed:	248.2505
# working on image: 185
# Time Elapsed:	248.2505
# working on image: 186
# Time Elapsed:	248.2505
# working on image: 187
# Time Elapsed:	248.2506
# working on image: 188
# Time Elapsed:	248.2506
# working on image: 189
# Time Elapsed:	248.2506
# working on image: 190
# Time Elapsed:	248.2506
# working on image: 191
# Time Elapsed:	248.2507
# working on image: 192
# Time Elapsed:	248.2507
# working on image: 193
# Time Elapsed:	248.2507
# working on image: 194
# Time Elapsed:	248.2508
# working on image: 195
# Time Elapsed:	248.2508
# working on image: 196
# Time Elapsed:	248.2509
# working on image: 197
# Time Elapsed:	248.2509
# working on image: 198
# Time Elapsed:	248.2509
# working on image: 199
# Time Elapsed:	248.2510
# working on image: 200
# Time Elapsed:	248.2510
# working on image: 201
# Time Elapsed:	248.2510
# working on image: 202
# Time Elapsed:	248.2510
# working on image: 203
# Time Elapsed:	248.2511
# working on image: 204
# Time Elapsed:	248.2511
# working on image: 205
# Time Elapsed:	248.2511
# working on image: 206
# Time Elapsed:	248.2511
# working on image: 207
# Time Elapsed:	248.2512
# working on image: 208
# Time Elapsed:	248.2512
# working on image: 209
# Time Elapsed:	248.2512
# working on image: 210
# Time Elapsed:	248.2512
# working on image: 211
# Time Elapsed:	248.2513
# working on image: 212
# Time Elapsed:	248.2513
# working on image: 213
# Time Elapsed:	248.2513
# working on image: 214
# Time Elapsed:	248.2514
# working on image: 215
# Time Elapsed:	248.2514
# working on image: 216
# Time Elapsed:	248.2514
# working on image: 217
# Time Elapsed:	248.2514
# working on image: 218
# Time Elapsed:	248.2515
# working on image: 219
# Time Elapsed:	248.2515
# working on image: 220
# Time Elapsed:	248.2515
# working on image: 221
# Time Elapsed:	248.2515
# working on image: 222
# Time Elapsed:	248.2516
# working on image: 223
# Time Elapsed:	248.2516
# working on image: 224
# Time Elapsed:	248.2517
# working on image: 225
# Time Elapsed:	248.2517
# working on image: 226
# Time Elapsed:	248.2518
# working on image: 227
# Time Elapsed:	248.2518
# working on image: 228
# Time Elapsed:	248.2518
# working on image: 229
# Time Elapsed:	248.2518
# working on image: 230
# Time Elapsed:	248.2519
# working on image: 231
# Time Elapsed:	248.2519
# working on image: 232
# Time Elapsed:	248.2519
# working on image: 233
# Time Elapsed:	248.2519
# working on image: 234
# Time Elapsed:	248.2520
# working on image: 235
# Time Elapsed:	248.2520
# working on image: 236
# Time Elapsed:	248.2520
# working on image: 237
# Time Elapsed:	248.2521
# working on image: 238
# Time Elapsed:	248.2521
# working on image: 239
# Time Elapsed:	248.2521
# working on image: 240
# Time Elapsed:	248.2521
# working on image: 241
# Time Elapsed:	248.2522
# working on image: 242
# Time Elapsed:	248.2522
# working on image: 243
# Time Elapsed:	248.2522
# working on image: 244
# Time Elapsed:	248.2522
# working on image: 245
# Time Elapsed:	248.2523
# working on image: 246
# Time Elapsed:	248.2523
# working on image: 247
# Time Elapsed:	248.2523
# working on image: 248
# Time Elapsed:	248.2523
# working on image: 249
# Time Elapsed:	248.2524
# working on image: 250
# Time Elapsed:	248.2524
# working on image: 251
# Time Elapsed:	248.2524
# working on image: 252
# Time Elapsed:	248.2524
# working on image: 253
# Time Elapsed:	248.2525
# working on image: 254
# Time Elapsed:	248.2525
# working on image: 255
# Time Elapsed:	248.2525
# working on image: 256
# Time Elapsed:	248.2525
# working on image: 257
# Time Elapsed:	248.2526
# working on image: 258
# Time Elapsed:	248.2526
# working on image: 259
# Time Elapsed:	248.2526
# working on image: 260
# Time Elapsed:	248.2527
# working on image: 261
# Time Elapsed:	248.2527
# working on image: 262
# Time Elapsed:	248.2527
# working on image: 263
# Time Elapsed:	248.2527
# working on image: 264
# Time Elapsed:	248.2528
# working on image: 265
# Time Elapsed:	248.2528
# working on image: 266
# Time Elapsed:	248.2528
# working on image: 267
# Time Elapsed:	248.2528
# working on image: 268
# Time Elapsed:	248.2529
# working on image: 269
# Time Elapsed:	248.2529
# working on image: 270
# Time Elapsed:	248.2529
# working on image: 271
# Time Elapsed:	248.2529
# working on image: 272
# Time Elapsed:	248.2530
# working on image: 273
# Time Elapsed:	248.2530
# working on image: 274
# Time Elapsed:	248.2530
# working on image: 275
# Time Elapsed:	248.2530
# working on image: 276
# Time Elapsed:	248.2531
# working on image: 277
# Time Elapsed:	248.2531
# working on image: 278
# Time Elapsed:	248.2531
# working on image: 279
# Time Elapsed:	248.2532
# working on image: 280
# Time Elapsed:	248.2532
# working on image: 281
# Time Elapsed:	248.2532
# working on image: 282
# Time Elapsed:	248.2533
# working on image: 283
# Time Elapsed:	248.2533
# working on image: 284
# Time Elapsed:	248.2533
# working on image: 285
# Time Elapsed:	248.2533
# working on image: 286
# Time Elapsed:	248.2534
# working on image: 287
# Time Elapsed:	248.2534
# working on image: 288
# Time Elapsed:	248.2534
# working on image: 289
# Time Elapsed:	248.2534
# working on image: 290
# Time Elapsed:	248.2535
# working on image: 291
# Time Elapsed:	248.2535
# working on image: 292
# Time Elapsed:	248.2535
# working on image: 293
# Time Elapsed:	248.2536
# working on image: 294
# Time Elapsed:	248.2536
# working on image: 295
# Time Elapsed:	248.2536
# working on image: 296
# Time Elapsed:	248.2536
# working on image: 297
# Time Elapsed:	248.2537
# working on image: 298
# Time Elapsed:	248.2537
# working on image: 299
# Time Elapsed:	248.2537
# working on image: 300
# Time Elapsed:	248.2537
# working on image: 301
# Time Elapsed:	248.2538
# working on image: 302
# Time Elapsed:	248.2538
# working on image: 303
# Time Elapsed:	248.2538
# working on image: 304
# Time Elapsed:	248.2538
# working on image: 305
# Time Elapsed:	248.2539
# working on image: 306
# Time Elapsed:	248.2539
# working on image: 307
# Time Elapsed:	248.2539
# working on image: 308
# Time Elapsed:	248.2539
# working on image: 309
# Time Elapsed:	248.2540
# working on image: 310
# Time Elapsed:	248.2540
# working on image: 311
# Time Elapsed:	248.2540
# working on image: 312
# Time Elapsed:	248.2541
# working on image: 313
# Time Elapsed:	248.2541
# working on image: 314
# Time Elapsed:	248.2541
# working on image: 315
# Time Elapsed:	248.2541
# working on image: 316
# Time Elapsed:	248.2542
# working on image: 317
# Time Elapsed:	248.2542
# working on image: 318
# Time Elapsed:	248.2542
# working on image: 319
# Time Elapsed:	248.2542
# working on image: 320
# Time Elapsed:	248.2543
# working on image: 321
# Time Elapsed:	248.2543
# working on image: 322
# Time Elapsed:	248.2543
# working on image: 323
# Time Elapsed:	248.2543
# working on image: 324
# Time Elapsed:	248.2544
# working on image: 325
# Time Elapsed:	248.2544
# working on image: 326
# Time Elapsed:	248.2544
# working on image: 327
# Time Elapsed:	248.2545
# working on image: 328
# Time Elapsed:	248.2545
# working on image: 329
# Time Elapsed:	248.2545
# working on image: 330
# Time Elapsed:	248.2545
# working on image: 331
# Time Elapsed:	248.2546
# working on image: 332
# Time Elapsed:	248.2546
# working on image: 333
# Time Elapsed:	248.2546
# working on image: 334
# Time Elapsed:	248.2546
# working on image: 335
# Time Elapsed:	248.2547
# working on image: 336
# Time Elapsed:	248.2547
# working on image: 337
# Time Elapsed:	248.2547
# working on image: 338
# Time Elapsed:	248.2547
# working on image: 339
# Time Elapsed:	248.2548
# Total Time Elapsed:	248.2548

# %%
print(len(results_remain_blk2))
print(results_remain_blk2[5])
print([i for i in range(1,5,1)])
# Out:
# 339
# []
# [1, 2, 3, 4]

# %%
df_remain_blk2 = results_remain_blk2[0][0]
for i in range(1,5,1):
    newdf = results_remain_blk2[i][0]
    df_remain_blk2 = pd.concat([df_remain_blk2, newdf], axis=0)
df_remain_blk2.to_csv(os.path.join(output_dir,"block2_segmentation_part2.txt"),index=False)

# %% [markdown]
# # Inference on block 3 images and only two scenes per image

# %% [markdown]
# ### ray.shutdown()

# %%
all_files_blk3 = [os.path.join(path,name) 
        for path, dirs, files in os.walk(os.path.join(data_dir, 'Block3/'))
        for name in files
        if name.endswith('.czi')]

# %%
ids_blk3 = [inference.remote(os.path.join(path,name), 'Block3/', diffs[1], predictor) 
        for path, dirs, files in os.walk(os.path.join(data_dir, 'Block3/'))
        for name in files
        if name.endswith('.czi')]

#results_blk3 = list() #creates a new dataframe that's empty
t0 = time.time()
for i in range(1,400,1):
    ready, not_ready = ray.wait(ids_blk3, num_returns = 1)
    print('image:', i) 
    results_blk3.append(ray.get(ready))
    ids_blk3 = not_ready
    if not ids_blk3: 
        break
    print('Time Elapsed:\t{:.4f}'.format(time.time() - t0))
print('Total Time Elapsed:\t{:.4f}'.format(time.time() - t0))
# Out:
# (raylet) Spilled 2186 MiB, 13 objects, write throughput 836 MiB/s. Set RAY_verbose_spill_logs=0 to disable this message.
# (raylet) Spilled 4205 MiB, 25 objects, write throughput 780 MiB/s.
# (raylet) Spilled 8241 MiB, 49 objects, write throughput 659 MiB/s.
# (raylet) Spilled 16820 MiB, 100 objects, write throughput 623 MiB/s.
# (raylet) Spilled 32799 MiB, 195 objects, write throughput 610 MiB/s.
# image: 1
# Time Elapsed:	0.0081
# image: 2
# Time Elapsed:	20.9100
# image: 3
# Time Elapsed:	35.3598
# image: 4
# Time Elapsed:	54.0779
# image: 5
# Time Elapsed:	98.7557
# image: 6
# Time Elapsed:	116.8642
# image: 7
# Time Elapsed:	129.0020
# image: 8
# Time Elapsed:	153.8187
# image: 9
# Time Elapsed:	197.2197
# image: 10
# Time Elapsed:	321.8907
# image: 11
# Time Elapsed:	323.5673
# image: 12
# Time Elapsed:	329.8097
# image: 13
# Time Elapsed:	379.1117
# image: 14
# Time Elapsed:	395.9407
# image: 15
# Time Elapsed:	402.5625
# image: 16
# Time Elapsed:	412.4789
# image: 17
# Time Elapsed:	437.1791
# image: 18
# Time Elapsed:	483.1547
# image: 19
# Time Elapsed:	492.8017
# image: 20
# Time Elapsed:	590.9222
# image: 21
# Time Elapsed:	645.0212
# image: 22
# Time Elapsed:	717.7729
# image: 23
# Time Elapsed:	726.7687
# image: 24
# Time Elapsed:	731.1083
# image: 25
# Time Elapsed:	747.7204
# image: 26
# Time Elapsed:	756.3941
# image: 27
# Time Elapsed:	780.4761
# image: 28
# Time Elapsed:	895.8038
# image: 29
# Time Elapsed:	954.6699
# image: 30
# Time Elapsed:	994.6259
# image: 31
# Time Elapsed:	1003.9820
# image: 32
# Time Elapsed:	1011.2520
# image: 33
# Time Elapsed:	1019.7675
# image: 34
# Time Elapsed:	1020.8866
# image: 35
# Time Elapsed:	1095.8178
# image: 36
# Time Elapsed:	1221.7692
# image: 37
# Time Elapsed:	1254.9054
# image: 38
# Time Elapsed:	1259.0382
# image: 39
# Time Elapsed:	1349.2592
# image: 40
# Time Elapsed:	1356.7410
# image: 41
# Time Elapsed:	1401.6468
# image: 42
# Time Elapsed:	1417.0670
# image: 43
# Time Elapsed:	1508.3148
# image: 44
# Time Elapsed:	1512.2546
# image: 45
# Time Elapsed:	1553.5150
# image: 46
# Time Elapsed:	1562.4456
# image: 47
# Time Elapsed:	1600.2855
# image: 48
# Time Elapsed:	1602.3591
# image: 49
# Time Elapsed:	1679.8725
# image: 50
# Time Elapsed:	1706.7724
# image: 51
# Time Elapsed:	1724.4540
# image: 52
# Time Elapsed:	1773.2768
# image: 53
# Time Elapsed:	1790.7461
# image: 54
# Time Elapsed:	1834.4050
# image: 55
# Time Elapsed:	1868.4879
# image: 56
# Time Elapsed:	1887.1470
# image: 57
# Time Elapsed:	1889.1877
# image: 58
# Time Elapsed:	1945.0363
# image: 59
# Time Elapsed:	1986.0869
# image: 60
# Time Elapsed:	2030.8769
# image: 61
# Time Elapsed:	2045.7777
# image: 62
# Time Elapsed:	2146.6599
# image: 63
# Time Elapsed:	2150.5168
# image: 64
# Time Elapsed:	2173.0460
# image: 65
# Time Elapsed:	2188.5849
# image: 66
# Time Elapsed:	2219.0813
# image: 67
# Time Elapsed:	2274.3417
# image: 68
# Time Elapsed:	2373.3272
# image: 69
# Time Elapsed:	2387.1118
# image: 70
# Time Elapsed:	2397.4256
# image: 71
# Time Elapsed:	2423.3518
# image: 72
# Time Elapsed:	2426.4294
# image: 73
# Time Elapsed:	2446.4168
# image: 74
# Time Elapsed:	2486.7121
# image: 75
# Time Elapsed:	2488.7382
# image: 76
# Time Elapsed:	2538.8059
# image: 77
# Time Elapsed:	2622.6748
# image: 78
# Time Elapsed:	2656.3330
# image: 79
# Time Elapsed:	2664.5980
# image: 80
# Time Elapsed:	2666.1442
# image: 81
# Time Elapsed:	2776.1646
# image: 82
# Time Elapsed:	2779.3033
# image: 83
# Time Elapsed:	2832.8337
# image: 84
# Time Elapsed:	2849.3634
# image: 85
# Time Elapsed:	2860.4811
# image: 86
# Time Elapsed:	2888.9648
# image: 87
# Time Elapsed:	2990.8750
# image: 88
# Time Elapsed:	3011.2982
# image: 89
# ---------------------------------------------------------------------------
# RayTaskError(IndexError)                  Traceback (most recent call last)
# Cell In[16], line 11
#       9 ready, not_ready = ray.wait(ids_blk3, num_returns = 1)
#      10 print('image:', i)
# ---> 11 results_blk3.append(ray.get(ready))
#      12 ids_blk3 = not_ready
#      13 if not ids_blk3:
#
# File ~/opt/anaconda3/envs/detectron2-py38/lib/python3.8/site-packages/ray/_private/auto_init_hook.py:24, in wrap_auto_init.<locals>.auto_init_wrapper(*args, **kwargs)
#      21 @wraps(fn)
#      22 def auto_init_wrapper(*args, **kwargs):
#      23     auto_init_ray()
# ---> 24     return fn(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/detectron2-py38/lib/python3.8/site-packages/ray/_private/client_mode_hook.py:103, in client_mode_hook.<locals>.wrapper(*args, **kwargs)
#     101     if func.__name__ != "init" or is_client_mode_enabled_by_default:
#     102         return getattr(ray, func.__name__)(*args, **kwargs)
# --> 103 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/detectron2-py38/lib/python3.8/site-packages/ray/_private/worker.py:2524, in get(object_refs, timeout)
#    2522     worker.core_worker.dump_object_store_memory_usage()
#    2523 if isinstance(value, RayTaskError):
# -> 2524     raise value.as_instanceof_cause()
#    2525 else:
#    2526     raise value
#
# RayTaskError(IndexError): ray::inference() (pid=973, ip=127.0.0.1)
#   File "/var/folders/mv/p4jr8xs52gl7rk_wf4pn6mn80000gn/T/ipykernel_929/813364551.py", line 58, in inference
# IndexError: list index out of range

# %%
print(len(results_blk3))
# Out:
# 88

# %%
print(len(all_files_blk3))
print(all_files_blk3[332])
print(all_files_blk3[331:333])
# Out:
# 333
# /Volumes/easystore/GWAS 2022/Block3/PI92270/PI92270_C01_R12.czi
# ['/Volumes/easystore/GWAS 2022/Block3/PI656065/PI656065_C06_R15.czi', '/Volumes/easystore/GWAS 2022/Block3/PI92270/PI92270_C01_R12.czi']

# %%
ray.init(num_cpus=18, ignore_reinit_error=True)
# Out:
# 2023-09-29 16:05:23,661	INFO worker.py:1612 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# RayContext(dashboard_url='127.0.0.1:8265', python_version='3.8.18', ray_version='2.6.3', ray_commit='8a434b4ee7cd48e60fa1531315d39901fac5d79e', protocol_version=None)

# %%
ids_blk3 = [inference.remote(path, 'Block3/', diffs[1], predictor) 
        for path in all_files_blk3[88:333]]

#results_blk3 = list() #creates a new dataframe that's empty
t0 = time.time()
for i in range(1,400,1):
    ready, not_ready = ray.wait(ids_blk3, num_returns = 1)
    print('image:', i) 
    results_blk3.append(ray.get(ready))
    ids_blk3 = not_ready
    if not ids_blk3: 
        break
    print('Time Elapsed:\t{:.4f}'.format(time.time() - t0))
print('Total Time Elapsed:\t{:.4f}'.format(time.time() - t0))
# Out:
# (raylet) Spilled 2691 MiB, 16 objects, write throughput 940 MiB/s. Set RAY_verbose_spill_logs=0 to disable this message.
# (raylet) Spilled 4541 MiB, 27 objects, write throughput 976 MiB/s.
# (raylet) Spilled 8410 MiB, 50 objects, write throughput 1011 MiB/s.
# (raylet) Spilled 16483 MiB, 98 objects, write throughput 884 MiB/s.
# (raylet) Spilled 32799 MiB, 195 objects, write throughput 732 MiB/s.
# image: 1
# Time Elapsed:	133.3312
# image: 2
# Time Elapsed:	135.5714
# image: 3
# Time Elapsed:	144.0336
# image: 4
# Time Elapsed:	157.1833
# image: 5
# ---------------------------------------------------------------------------
# RayTaskError(IndexError)                  Traceback (most recent call last)
# Cell In[31], line 9
#       7 ready, not_ready = ray.wait(ids_blk3, num_returns = 1)
#       8 print('image:', i)
# ----> 9 results_blk3.append(ray.get(ready))
#      10 ids_blk3 = not_ready
#      11 if not ids_blk3:
#
# File ~/opt/anaconda3/envs/detectron2-py38/lib/python3.8/site-packages/ray/_private/auto_init_hook.py:24, in wrap_auto_init.<locals>.auto_init_wrapper(*args, **kwargs)
#      21 @wraps(fn)
#      22 def auto_init_wrapper(*args, **kwargs):
#      23     auto_init_ray()
# ---> 24     return fn(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/detectron2-py38/lib/python3.8/site-packages/ray/_private/client_mode_hook.py:103, in client_mode_hook.<locals>.wrapper(*args, **kwargs)
#     101     if func.__name__ != "init" or is_client_mode_enabled_by_default:
#     102         return getattr(ray, func.__name__)(*args, **kwargs)
# --> 103 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/detectron2-py38/lib/python3.8/site-packages/ray/_private/worker.py:2524, in get(object_refs, timeout)
#    2522     worker.core_worker.dump_object_store_memory_usage()
#    2523 if isinstance(value, RayTaskError):
# -> 2524     raise value.as_instanceof_cause()
#    2525 else:
#    2526     raise value
#
# RayTaskError(IndexError): ray::inference() (pid=3663, ip=127.0.0.1)
#   File "/var/folders/mv/p4jr8xs52gl7rk_wf4pn6mn80000gn/T/ipykernel_929/813364551.py", line 58, in inference
# IndexError: list index out of range

# %%
ray memory
# Out:
#   Cell In[33], line 1
#     ray memory
#         ^
# SyntaxError: invalid syntax

# %%
allpath2block3img = [os.path.join(path,name) for path, dirs, files in os.walk(os.path.join(data_dir,'Block3/'))
for name in files
if name.endswith('.czi')]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[278], line 1
# ----> 1 allpath2block3img = [os.path.join(path,name) for path, dirs, files in os.walk(os.path.join(data_dir,'Block3/'))
#       2 for name in files
#       3 if name.endswith('.czi')]
#
# Cell In[278], line 1, in <listcomp>(.0)
# ----> 1 allpath2block3img = [os.path.join(path,name) for path, dirs, files in os.walk(os.path.join(data_dir,'Block3/'))
#       2 for name in files
#       3 if name.endswith('.czi')]
#
# File ~/opt/anaconda3/envs/detectron2-py38/lib/python3.8/os.py:412, in walk(top, topdown, onerror, followlinks)
#     407         new_path = join(top, dirname)
#     408         # Issue #23605: os.path.islink() is used instead of caching
#     409         # entry.is_symlink() result during the loop on os.scandir() because
#     410         # the caller can replace the directory entry during the "yield"
#     411         # above.
# --> 412         if followlinks or not islink(new_path):
#     413             yield from walk(new_path, topdown, onerror, followlinks)
#     414 else:
#     415     # Recurse into sub-directories
#
# File ~/opt/anaconda3/envs/detectron2-py38/lib/python3.8/posixpath.py:167, in islink(path)
#     165 """Test whether a path is a symbolic link"""
#     166 try:
# --> 167     st = os.lstat(path)
#     168 except (OSError, ValueError, AttributeError):
#     169     return False
#
# KeyboardInterrupt:

# %%
print(len(results_blk3[0]))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[281], line 1
# ----> 1 print(len(results_blk3[0]))
#
# IndexError: list index out of range

# %%
df_blk3 = results_blk3[0][0]
for i in range(1,len(results_blk3),1):
    newdf = results_blk3[i][0]
    df_blk3 = pd.concat([df_blk3, newdf], axis=0)
#df.to_csv(os.path.join(output_dir,"block3_segmentation.txt"),index=False)

# %%
ids = [inference.remote(os.path.join(path,name), 'Block8/', diffs[2], cfg) 
        for path, dirs, files in os.walk(os.path.join(data_dir, 'Block8/'))
        for name in files
        if name.endswith('.czi')]

results = list() #creates a new dataframe that's empty
t0 = time.time()
for i in range(1,400,1):
    ready, not_ready = ray.wait(ids, num_returns = 1)
    print('working on image:', i) 
    results.append(ray.get(ready))
    ids = not_ready
    if not ids: 
        break
    print('Time Elapsed:\t{:.4f}'.format(time.time() - t0))

# %%
df = results[0][0]
for i in range(1,len(results),1):
    newdf = results[i][0]
    df = pd.concat([df, newdf], axis=0)
df.to_csv(os.path.join(output_dir,"block8_segmentation.txt"),index=False)

# %%
import math
a = math.nan
print(type(a))
# Out:
# <class 'float'>
